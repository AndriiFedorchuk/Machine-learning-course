# %% [markdown]
# <a href="https://colab.research.google.com/github/AndriiFedorchuk/Andrii/blob/master/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install sklearn
#!pip install pandas
#!pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: numpy>=1.9.1 in /tensorflow-2.1.0/python3.6 (from keras) (1.18.1)
# Requirement already satisfied: six>=1.9.0 in /tensorflow-2.1.0/python3.6 (from keras) (1.14.0)
# Requirement already satisfied: scipy>=0.14 in /tensorflow-2.1.0/python3.6 (from keras) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /tensorflow-2.1.0/python3.6 (from keras) (1.1.0)
# Requirement already satisfied: h5py in /tensorflow-2.1.0/python3.6 (from keras) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /tensorflow-2.1.0/python3.6 (from keras) (1.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy 
import pandas as pd
from sklearn.model_selection import train_test_split

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 1.x
except Exception:
  pass
import tensorflow as tf

from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
URL = 'https://raw.githubusercontent.com/AndriiFedorchuk/Andrii/master/main_fa.csv'
dataset = pd.read_csv(URL)
dataset.head(10)
# Out:
#    History  Psychology  Politics  ...  Adrenaline sports  Pets  Gender
# 0        1           5         1  ...                  4     4       1
# 1        1           3         4  ...                  2     5       1
# 2        1           2         1  ...                  5     5       1
# 3        4           4         5  ...                  1     1       1
# 4        3           2         3  ...                  2     1       1
# 5        5           3         4  ...                  3     2       0
# 6        3           3         1  ...                  1     5       1
# 7        5           2         3  ...                  2     5       0
# 8        3           2         1  ...                  1     1       1
# 9        3           2         3  ...                  2     2       1
#
# [10 rows x 33 columns]

# %%
dataset /= 5
dataset.head()
# Out:
#    History  Psychology  Politics  ...  Adrenaline sports  Pets  Gender
# 0      0.2         1.0       0.2  ...                0.8   0.8     0.2
# 1      0.2         0.6       0.8  ...                0.4   1.0     0.2
# 2      0.2         0.4       0.2  ...                1.0   1.0     0.2
# 3      0.8         0.8       1.0  ...                0.2   0.2     0.2
# 4      0.6         0.4       0.6  ...                0.4   0.2     0.2
#
# [5 rows x 33 columns]

# %%
x = dataset.iloc[:,:32].values
y = dataset.iloc[:,32].values

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1)

# %%
# print info about a shape of arrays
print(x_train.shape, 'train samples for parameters')
print(y_train.shape, 'train samples for output - Gender')
print(x_test.shape, 'test samples  for parameters')
print(y_test.shape, 'test samples for output - Gender')
# Out:
# (900, 32) train samples for parameters
# (900,) train samples for output - Gender
# (100, 32) test samples  for parameters
# (100,) test samples for output - Gender

# %%
#Dependencies
import keras
from keras.models import Sequential
from keras.layers import Dense

# Neural network
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(32,)))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _get_default_graph()
#      65     try:
# ---> 66         return tf.get_default_graph()
#      67     except AttributeError:
#
# AttributeError: module 'tensorflow' has no attribute 'get_default_graph'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-88-28c1d6e1a887> in <module>()
#       4
#       5 # Neural network
# ----> 6 model = Sequential()
#       7 model.add(Dense(32, activation='relu', input_shape=(32,)))
#       8 model.add(Dense(16, activation='relu'))
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/sequential.py in __init__(self, layers, name)
#      86
#      87     def __init__(self, layers=None, name=None):
# ---> 88         super(Sequential, self).__init__(name=name)
#      89         self._build_input_shape = None
#      90
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in __init__(self, *args, **kwargs)
#      95         else:
#      96             # Subclassed network
# ---> 97             self._init_subclassed_network(**kwargs)
#      98
#      99     def _base_init(self, name=None, trainable=True, dtype=None):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in _init_subclassed_network(self, name, **kwargs)
#     298
#     299     def _init_subclassed_network(self, name=None, **kwargs):
# --> 300         self._base_init(name=name, **kwargs)
#     301         self._is_graph_network = False
#     302         self._expects_training_arg = has_arg(self.call, 'training')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in _base_init(self, name, trainable, dtype)
#     108         if not name:
#     109             prefix = self.__class__.__name__.lower()
# --> 110             name = prefix + '_' + str(K.get_uid(prefix))
#     111         self.name = name
#     112
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in get_uid(prefix)
#      84     """
#      85     global _GRAPH_UID_DICTS
# ---> 86     graph = _get_default_graph()
#      87     if graph not in _GRAPH_UID_DICTS:
#      88         _GRAPH_UID_DICTS[graph] = defaultdict(int)
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _get_default_graph()
#      67     except AttributeError:
#      68         raise RuntimeError(
# ---> 69             'It looks like you are trying to use '
#      70             'a version of multi-backend Keras that '
#      71             'does not support TensorFlow 2.0. We recommend '
#
# RuntimeError: It looks like you are trying to use a version of multi-backend Keras that does not support TensorFlow 2.0. We recommend using `tf.keras`, or alternatively, downgrading to TensorFlow 1.14.

# %%
#train, test = train_test_split(dataframe, test_size=0.1)
#train, val = train_test_split(train, test_size=0.111)
#print(len(train), 'train examples')
#print(len(val), 'validation examples')
#print(len(test), 'test examples')
# Out:
# 800 train examples
# 100 validation examples
# 100 test examples

# %%
dataframe.shape
train.shape
val.shape
test.shape
# Out:
# (100, 33)

# %% [markdown]
# 1

# %%
#dataset=numpy.loadtxt("https://raw.githubusercontent.com/AndriiFedorchuk/Andrii/master/main_fa.csv",delimiter=",")
#split into input (X) and output (Y) variables
#X=dataset[:,0:32]
#Y=dataset[:,32]

#Gender = dataframe.temp
